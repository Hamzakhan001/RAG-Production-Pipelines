# %%
import os
from typing import List,Dict,Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain.text_splitter import (RecursiveCharacterTextSplitter,CharacterTextSplitter,TokenTextSplitter)

# %%
## Understanding Docuemnt Structure in Langchain 
document = Document(
    page_content="This is the first document created here",
    metadata = {
        "source":"example.txt",
        "page":1,
        "author":"Hamza Khan"
    }
)

print(f"Main document content: {document.metadata}")
# Out:
# Main document content: {'source': 'example.txt', 'page': 1, 'author': 'Hamza Khan'}

# %% [markdown]
# TextLoader- Reading Single Files

# %%
from langchain_community.document_loaders import TextLoader
from langchain.document_loaders import TextLoader


loader = TextLoader("filepath",encoding="utf-8")

# %%
#Loading whole directory of files
from langchain_community.document_loaders import DirectoryLoader

directory_loader = DirectoryLoader(
    "directory_path",
    glob = "**/*.txt", ## all files with .txt extensions
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs= {'encoding':'utf-8'}
)

docs = directory_loader.load()

# %% [markdown]
# Text Splitters

# %%
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter
 )
character_splitter = CharacterTextSplitter (
    separator= "\n",
    chunk_size = 200,
    chunk_overlap = 20,
    length_function = len
)


#character text splitter

# %% [markdown]
# Loading Files

# %%
from langchain_community.document_loaders import (
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader
)

# %%
try:
    pypdf_loader = PyPDFLoader()
    pypdf_doc = pypdf_loader.load()

except Exception as e:
    print(f"There is an error: {e}")
